# %% [markdown]
# # Build Vector Database from PDF
# This notebook processes PDF files and creates a FAISS vector database for RAG applications.

# %%
# Install required packages
# !pip install langchain pypdf2 faiss-cpu sentence-transformers
# Out:
# Requirement already satisfied: langchain in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.3.13)
# Requirement already satisfied: pypdf2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: faiss-cpu in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.9.0.post1)
# Requirement already satisfied: sentence-transformers in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.3.1)
# Requirement already satisfied: PyYAML>=5.3 in /home/codespace/.local/lib/python3.12/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain) (3.11.11)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.26 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain) (0.3.28)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain) (0.3.4)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain) (0.2.7)
# Requirement already satisfied: numpy<3,>=1.26.2 in /home/codespace/.local/lib/python3.12/site-packages (from langchain) (2.2.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain) (2.10.4)
# Requirement already satisfied: requests<3,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from langchain) (9.0.0)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.12/site-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from sentence-transformers) (4.47.1)
# Requirement already satisfied: tqdm in /usr/local/python/3.12.1/lib/python3.12/site-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from sentence-transformers) (2.3.0)
# Requirement already satisfied: scikit-learn in /home/codespace/.local/lib/python3.12/site-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: scipy in /home/codespace/.local/lib/python3.12/site-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from sentence-transformers) (0.27.0)
# Requirement already satisfied: Pillow in /home/codespace/.local/lib/python3.12/site-packages (from sentence-transformers) (11.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: filelock in /home/codespace/.local/lib/python/3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/codespace/.local/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.26->langchain) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/codespace/.local/lib/python3.12/site-packages (from langsmith<0.3,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langsmith<0.3,>=0.1.17->langchain) (3.10.13)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langsmith<0.3,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: sympy in /home/codespace/.local/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: networkx in /home/codespace/.local/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.6.85)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: joblib>=1.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: anyio in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (4.7.0)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/codespace/.local/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.26->langchain) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/codespace/.local/lib/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.3.1)

# %%
import os
from typing import List
from PyPDF2 import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

# %%
from PyPDF2 import PdfReader

def extract_toc(pdf_path):
    reader = PdfReader(pdf_path)
    if hasattr(reader, "outline"):
        toc = reader.outline
        return toc
    return None

pdf_path = "nlp_book.pdf"
toc = extract_toc(pdf_path)
for i in toc:
    print(i)
# Out:
# {'/Title': 'I Fundamental Algorithms for NLP', '/Page': IndirectObject(2156, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 665.681, '/Zoom': NullObject, '/Count': -12}
# [{'/Title': 'Introduction', '/Page': IndirectObject(2162, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 682.844, '/Zoom': NullObject}, {'/Title': 'Regular Expressions, Tokenization, Edit Distance', '/Page': IndirectObject(2171, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 682.844, '/Zoom': NullObject, '/Count': -11}, [{'/Title': 'Regular Expressions', '/Page': IndirectObject(2179, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 474.815, '/Zoom': NullObject, '/Count': -7}, [{'/Title': 'Basic Regular Expression Patterns', '/Page': IndirectObject(2179, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 177.454, '/Zoom': NullObject}, {'/Title': 'Disjunction, Grouping, and Precedence', '/Page': IndirectObject(2200, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 356.644, '/Zoom': NullObject}, {'/Title': 'A Simple Example', '/Page': IndirectObject(2204, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 376.891, '/Zoom': NullObject}, {'/Title': 'More Operators', '/Page': IndirectObject(2215, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 492.857, '/Zoom': NullObject}, {'/Title': 'A More Complex Example', '/Page': IndirectObject(2223, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 586.024, '/Zoom': NullObject}, {'/Title': 'Substitution, Capture Groups, and ELIZA', '/Page': IndirectObject(2223, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 107.409, '/Zoom': NullObject}, {'/Title': 'Lookahead Assertions', '/Page': IndirectObject(2251, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 494.498, '/Zoom': NullObject}], {'/Title': 'Words', '/Page': IndirectObject(2251, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 309.62, '/Zoom': NullObject}, {'/Title': 'Corpora', '/Page': IndirectObject(2291, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 248.631, '/Zoom': NullObject}, {'/Title': 'Simple Unix Tools for Word Tokenization', '/Page': IndirectObject(2326, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 654.684, '/Zoom': NullObject}, {'/Title': 'Word and Subword Tokenization', '/Page': IndirectObject(2335, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 140.978, '/Zoom': NullObject, '/Count': -2}, [{'/Title': 'Top-down (rule-based) tokenization', '/Page': IndirectObject(2343, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 571.397, '/Zoom': NullObject}, {'/Title': 'Byte-Pair Encoding: A Bottom-up Tokenization Algorithm', '/Page': IndirectObject(2391, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 616.921, '/Zoom': NullObject}], {'/Title': 'Word Normalization, Lemmatization and Stemming', '/Page': IndirectObject(2408, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 426.144, '/Zoom': NullObject, '/Count': -1}, [{'/Title': 'Lemmatization', '/Page': IndirectObject(2408, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 153.308, '/Zoom': NullObject}], {'/Title': 'Sentence Segmentation', '/Page': IndirectObject(2419, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 75.344, '/Zoom': NullObject}, {'/Title': 'Minimum Edit Distance', '/Page': IndirectObject(2432, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 405.198, '/Zoom': NullObject, '/Count': -1}, [{'/Title': 'The Minimum Edit Distance Algorithm', '/Page': IndirectObject(2446, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 406.667, '/Zoom': NullObject}], {'/Title': 'Summary', '/Page': IndirectObject(2516, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 176.873, '/Zoom': NullObject}, {'/Title': 'Bibliographical and Historical Notes', '/Page': IndirectObject(2516, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 176.873, '/Zoom': NullObject}, {'/Title': 'Exercises', '/Page': IndirectObject(2516, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 176.873, '/Zoom': NullOb ...
# {'/Title': 'II NLP Applications', '/Page': IndirectObject(8396, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 665.681, '/Zoom': NullObject, '/Count': -4}
# [{'/Title': 'Machine Translation', '/Page': IndirectObject(8405, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 682.844, '/Zoom': NullObject, '/Count': -10}, [{'/Title': 'Language Divergences and Typology', '/Page': IndirectObject(8431, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 200.754, '/Zoom': NullObject, '/Count': -4}, [{'/Title': 'Word Order Typology', '/Page': IndirectObject(8463, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 224.919, '/Zoom': NullObject}, {'/Title': 'Lexical Divergences', '/Page': IndirectObject(8477, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 308.605, '/Zoom': NullObject}, {'/Title': 'Morphological Typology', '/Page': IndirectObject(8498, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 177.68, '/Zoom': NullObject}, {'/Title': 'Referential density', '/Page': IndirectObject(8536, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 584.569, '/Zoom': NullObject}], {'/Title': 'Machine Translation using Encoder-Decoder', '/Page': IndirectObject(8536, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 261.62, '/Zoom': NullObject, '/Count': -2}, [{'/Title': 'Tokenization', '/Page': IndirectObject(8547, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 392.5, '/Zoom': NullObject}, {'/Title': 'Creating the Training data', '/Page': IndirectObject(8579, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 222.361, '/Zoom': NullObject}], {'/Title': 'Details of the Encoder-Decoder Model', '/Page': IndirectObject(8648, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 629.038, '/Zoom': NullObject}, {'/Title': 'Decoding in MT: Beam Search', '/Page': IndirectObject(8697, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 553.684, '/Zoom': NullObject, '/Count': -1}, [{'/Title': 'Minimum Bayes Risk Decoding', '/Page': IndirectObject(8776, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 106.326, '/Zoom': NullObject}], {'/Title': 'Translating in low-resource situations', '/Page': IndirectObject(8791, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 275.422, '/Zoom': NullObject, '/Count': -3}, [{'/Title': 'Data Augmentation', '/Page': IndirectObject(8791, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 75.344, '/Zoom': NullObject}, {'/Title': 'Multilingual models', '/Page': IndirectObject(8810, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 313.26, '/Zoom': NullObject}, {'/Title': 'Sociotechnical issues', '/Page': IndirectObject(8828, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 682.844, '/Zoom': NullObject}], {'/Title': 'MT Evaluation', '/Page': IndirectObject(8828, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 314.424, '/Zoom': NullObject, '/Count': -3}, [{'/Title': 'Using Human Raters to Evaluate MT', '/Page': IndirectObject(8828, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 167.16, '/Zoom': NullObject}, {'/Title': 'Automatic Evaluation', '/Page': IndirectObject(8845, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 430.102, '/Zoom': NullObject}, {'/Title': 'Automatic Evaluation: Embedding-Based Methods', '/Page': IndirectObject(8871, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 153.973, '/Zoom': NullObject}], {'/Title': 'Bias and Ethical Issues', '/Page': IndirectObject(8898, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 241.551, '/Zoom': NullObject}, {'/Title': 'Summary', '/Page': IndirectObject(9064, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 333.808, '/Zoom': NullObject}, {'/Title': 'Bibliographical and Historical Notes', '/Page': IndirectObject(9064, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 333.808, '/Zoom': NullObject}, {'/Title': 'Exercises', '/Page': IndirectObject(9149, 0, 124214675915072), '/Type': '/XYZ', '/Left': 493.2, '/Top': 572.862, '/Zoom': NullObject}], {'/Title': 'Ques ...
# {'/Title': 'III Annotating Linguistic Structure', '/Page': IndirectObject(11386, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 665.681, '/Zoom': NullObject, '/Count': -10}
# [{'/Title': 'Sequence Labeling for Parts of Speech and Named Entities', '/Page': IndirectObject(11401, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 682.844, '/Zoom': NullObject, '/Count': -10}, [{'/Title': '(Mostly) English Word Classes', '/Page': IndirectObject(11401, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 75.344, '/Zoom': NullObject}, {'/Title': 'Part-of-Speech Tagging', '/Page': IndirectObject(11429, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 214.779, '/Zoom': NullObject}, {'/Title': 'Named Entities and Named Entity Tagging', '/Page': IndirectObject(11475, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 641.564, '/Zoom': NullObject}, {'/Title': 'HMM Part-of-Speech Tagging', '/Page': IndirectObject(11495, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 682.844, '/Zoom': NullObject, '/Count': -6}, [{'/Title': 'Markov Chains', '/Page': IndirectObject(11495, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 526.619, '/Zoom': NullObject}, {'/Title': 'The Hidden Markov Model', '/Page': IndirectObject(11565, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 467.264, '/Zoom': NullObject}, {'/Title': 'The components of an HMM tagger', '/Page': IndirectObject(11576, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 682.844, '/Zoom': NullObject}, {'/Title': 'HMM tagging as decoding', '/Page': IndirectObject(11646, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 632.54, '/Zoom': NullObject}, {'/Title': 'The Viterbi Algorithm', '/Page': IndirectObject(11658, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 423.61, '/Zoom': NullObject}, {'/Title': 'Working through an example', '/Page': IndirectObject(11671, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 358.494, '/Zoom': NullObject}], {'/Title': 'Conditional Random Fields (CRFs)', '/Page': IndirectObject(12059, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 494.166, '/Zoom': NullObject, '/Count': -3}, [{'/Title': 'Features in a CRF POS Tagger', '/Page': IndirectObject(12076, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 682.844, '/Zoom': NullObject}, {'/Title': 'Features for CRF Named Entity Recognizers', '/Page': IndirectObject(12087, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 435.663, '/Zoom': NullObject}, {'/Title': 'Inference and Training for CRFs', '/Page': IndirectObject(12098, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 398.582, '/Zoom': NullObject}], {'/Title': 'Evaluation of Named Entity Recognition', '/Page': IndirectObject(12114, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 403.203, '/Zoom': NullObject}, {'/Title': 'Further Details ', '/Page': IndirectObject(12114, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 140.978, '/Zoom': NullObject, '/Count': -2}, [{'/Title': 'Rule-based Methods', '/Page': IndirectObject(12139, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 573.779, '/Zoom': NullObject}, {'/Title': 'POS Tagging for Morphologically Rich Languages', '/Page': IndirectObject(12139, 0, 124214675915072), '/Type': '/XYZ', '/Left': 142.2, '/Top': 260.863, '/Zoom': NullObject}], {'/Title': 'Summary', '/Page': IndirectObject(12164, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 420.937, '/Zoom': NullObject}, {'/Title': 'Bibliographical and Historical Notes', '/Page': IndirectObject(12164, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 420.937, '/Zoom': NullObject}, {'/Title': 'Exercises', '/Page': IndirectObject(12164, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 420.937, '/Zoom': NullObject}], {'/Title': 'Context-Free Grammars and Constituency Parsing', '/Page': IndirectObject(12342, 0, 124214675915072), '/Type': '/XYZ', '/Left': 160.2, '/Top': 682.844, '/Zoom': NullObject, '/Count': -12}, [{'/Title': 'Constituency', '/Page': IndirectObject(12354, 0, 124214 ...

# %%
from PyPDF2 import PdfReader

def parse_toc(toc, results=None, level=0):
    """
    Đệ quy duyệt qua mục lục PDF và lưu các tiêu đề và số trang vào danh sách kết quả.

    Args:
        toc: Mục lục PDF, thường là một danh sách các dictionary hoặc danh sách lồng nhau.
        results: Danh sách chứa kết quả (mặc định là None, sẽ khởi tạo một danh sách mới).
        level: Mức độ lồng nhau (cấp độ của mục lục).

    Returns:
        results: Danh sách các mục lục với tiêu đề và số trang.
    """
    if results is None:
        results = []

    for item in toc:
        if isinstance(item, dict):  # Mục đơn
            title = item.get('/Title', 'Unknown Title')
            page = item.get('/Page', None)
            if page:  # Nếu có trang, giải mã số trang
                page_number = page.idnum - 1  # Chuyển đổi IndirectObject sang số trang
            else:
                page_number = None
            results.append({'title': title, 'page': page_number, 'level': level})
        elif isinstance(item, list):  # Mục lồng nhau
            parse_toc(item, results, level + 1)

    return results


def extract_toc_with_pages(pdf_path):
    """
    Trích xuất mục lục từ file PDF và giải mã tiêu đề, số trang.

    Args:
        pdf_path: Đường dẫn tới file PDF.

    Returns:
        List: Danh sách các mục lục với tiêu đề và số trang.
    """
    reader = PdfReader(pdf_path)

    if hasattr(reader, "outline"):
        toc = reader.outline
        results = parse_toc(toc)
        return results
    else:
        print("Không tìm thấy mục lục trong file PDF.")
        return None


# Đường dẫn tới file PDF
pdf_path = "nlp_book.pdf"

# Gọi hàm để trích xuất mục lục
toc_results = extract_toc_with_pages(pdf_path)

# Hiển thị kết quả
if toc_results:
    for entry in toc_results:
        indent = "  " * entry['level']  # Tạo thụt lề theo cấp độ
        print(f"{indent}Title: {entry['title']}, Page: {entry['page']}")
# Out:
# Title: I Fundamental Algorithms for NLP, Page: 2155
#   Title: Introduction, Page: 2161
#   Title: Regular Expressions, Tokenization, Edit Distance, Page: 2170
#     Title: Regular Expressions, Page: 2178
#       Title: Basic Regular Expression Patterns, Page: 2178
#       Title: Disjunction, Grouping, and Precedence, Page: 2199
#       Title: A Simple Example, Page: 2203
#       Title: More Operators, Page: 2214
#       Title: A More Complex Example, Page: 2222
#       Title: Substitution, Capture Groups, and ELIZA, Page: 2222
#       Title: Lookahead Assertions, Page: 2250
#     Title: Words, Page: 2250
#     Title: Corpora, Page: 2290
#     Title: Simple Unix Tools for Word Tokenization, Page: 2325
#     Title: Word and Subword Tokenization, Page: 2334
#       Title: Top-down (rule-based) tokenization, Page: 2342
#       Title: Byte-Pair Encoding: A Bottom-up Tokenization Algorithm, Page: 2390
#     Title: Word Normalization, Lemmatization and Stemming, Page: 2407
#       Title: Lemmatization, Page: 2407
#     Title: Sentence Segmentation, Page: 2418
#     Title: Minimum Edit Distance, Page: 2431
#       Title: The Minimum Edit Distance Algorithm, Page: 2445
#     Title: Summary, Page: 2515
#     Title: Bibliographical and Historical Notes, Page: 2515
#     Title: Exercises, Page: 2515
#   Title: N-gram Language Models, Page: 2594
#     Title: N-Grams, Page: 2602
#       Title: The Markov assumption, Page: 2613
#       Title: How to estimate probabilities, Page: 2628
#       Title: Dealing with scale in large n-gram models, Page: 2661
#     Title: Evaluating Language Models: Training and Test Sets, Page: 2675
#     Title: Evaluating Language Models: Perplexity, Page: 2684
#       Title: Perplexity as Weighted Average Branching Factor, Page: 2705
#     Title: Sampling sentences from a language model, Page: 2718
#     Title: Generalizing vs. overfitting the training set, Page: 2739
#     Title: Smoothing, Interpolation, and Backoff, Page: 2762
#       Title: Laplace Smoothing, Page: 2762
#       Title: Add-k smoothing, Page: 2787
#       Title: Language Model Interpolation, Page: 2805
#       Title: Stupid Backoff, Page: 2805
#     Title: Advanced: Perplexity's Relation to Entropy, Page: 2821
#     Title: Summary, Page: 2863
#     Title: Bibliographical and Historical Notes, Page: 2863
#     Title: Exercises, Page: 2863
#   Title: Naive Bayes, Text Classification, and Sentiment, Page: 2958
#     Title: Naive Bayes Classifiers, Page: 2963
#     Title: Training the Naive Bayes Classifier, Page: 3023
#     Title: Worked example, Page: 3036
#     Title: Optimizing for Sentiment Analysis, Page: 3045
#     Title: Naive Bayes for other text classification tasks, Page: 3068
#     Title: Naive Bayes as a Language Model, Page: 3087
#     Title: Evaluation: Precision, Recall, F-measure, Page: 3099
#       Title: Evaluating with more than two classes, Page: 3138
#     Title: Test sets and Cross-validation, Page: 3138
#     Title: Statistical Significance Testing, Page: 3170
#       Title: The Paired Bootstrap Test, Page: 3230
#     Title: Avoiding Harms in Classification, Page: 3275
#     Title: Summary, Page: 3288
#     Title: Bibliographical and Historical Notes, Page: 3288
#     Title: Exercises, Page: 3288
#   Title: Logistic Regression, Page: 3403
#     Title: The sigmoid function, Page: 3408
#     Title: Classification with Logistic Regression, Page: 3434
#       Title: Sentiment Classification, Page: 3445
#       Title: Other classification tasks and features, Page: 3479
#       Title: Processing many examples at once, Page: 3488
#       Title: Choosing a classifier, Page: 3503
#     Title: Multinomial logistic regression, Page: 3503
#       Title: Softmax, Page: 3512
#       Title: Applying softmax in logistic regression, Page: 3512
#       Title: Features in Multinomial Logistic Regression, Page: 3524
#     Title: Learning in Logistic Regression, Page: 3524
#     Title: The cross-entropy loss function, Page: 3621
#     Title: Gradient Descent, Page: 3635
#       Title: The Gradient for Logistic Regression, Page: 3702
#       Title: The Stochastic Gradient Descent Algorithm, Page: 3702
#       Title: Working through an example, Page: 3702
#       Title: Mini-batch training, Page: 3722
#     Title: Regularization, Page: 3730
#     Title: Learning in Multinomial Logistic Regression, Page: 3745
#     Title: Interpreting models, Page: 3765
#     Title: Advanced: Deriving the Gradient Equation, Page: 3773
#     Title: Summary, Page: 3785
#     Title: Bibliographical and Historical Notes, Page: 3785
#     Title: Exercises, Page: 3785
#   Title: Vector Semantics and Embeddings, Page: 3853
#     Title: Lexical Semantics, Page: 3853
#     Title: Vector Semantics, Page: 3930
#     Title: Words and Vectors, Page: 3943
#       Title: Vectors and documents, Page: 3943
#       Title: Words as vectors: document dimensions, Page: 3987
#       Title: Words as vectors: word dimensions, Page: 4022
#     Title: Cosine for measuring similarity, Page: 4056
#     Title: TF-IDF: Weighing terms in the vector, Page: 4068
#     Title: Pointwise Mutual Information (PMI), Page: 4145
#     Title: Applications of the tf-idf or PPMI vector models, Page: 4182
#     Title: Word2vec, Page: 4193
#       Title: The classifier, Page: 4205
#       Title: Learning skip-gram embeddings, Page: 4234
#       Title: Other kinds of static embeddings, Page: 4346
#     Title: Visualizing Embeddings, Page: 4346
#     Title: Semantic properties of embeddings, Page: 4392
#       Title: Embeddings and Historical Semantics, Page: 4511
#     Title: Bias and Embeddings, Page: 4511
#     Title: Evaluating Vector Models, Page: 4568
#     Title: Summary, Page: 4606
#     Title: Bibliographical and Historical Notes, Page: 4606
#     Title: Exercises, Page: 4606
#   Title: Neural Networks, Page: 4788
#     Title: Units, Page: 4788
#     Title: The XOR problem, Page: 4854
#       Title: The solution: neural networks, Page: 4875
#     Title: Feedforward Neural Networks, Page: 4911
#       Title: More details on feedforward networks, Page: 5031
#     Title: Feedforward networks for NLP: Classification, Page: 5042
#     Title: Training Neural Nets, Page: 5168
#       Title: Loss function, Page: 5168
#       Title: Computing the Gradient, Page: 5179
#       Title: Computation Graphs, Page: 5192
#       Title: Backward differentiation on computation graphs, Page: 5192
#       Title: More details on learning, Page: 5346
#     Title: Feedforward Neural Language Modeling, Page: 5360
#       Title: Forward inference in the neural language model, Page: 5372
#     Title: Training the neural language model, Page: 5445
#     Title: Summary, Page: 5453
#     Title: Bibliographical and Historical Notes, Page: 5453
#   Title: RNNs and LSTMs, Page: 5570
#     Title: Recurrent Neural Networks, Page: 5570
#       Title: Inference in RNNs, Page: 5577
#       Title: Training, Page: 5601
#     Title: RNNs as Language Models, Page: 5662
#       Title: Forward Inference in an RNN language model, Page: 5662
#       Title: Training an RNN language model, Page: 5670
#       Title: Weight Tying, Page: 5695
#     Title: RNNs for other NLP tasks, Page: 5795
#       Title: Sequence Labeling, Page: 5795
#       Title: RNNs for Sequence Classification, Page: 5806
#       Title: Generation with RNN-Based Language Models, Page: 5854
#     Title: Stacked and Bidirectional RNN architectures, Page: 5864
#       Title: Stacked RNNs, Page: 5864
#       Title: Bidirectional RNNs, Page: 5894
#     Title: The LSTM, Page: 5932
#       Title: Gated Units, Layers and Networks, Page: 6018
#     Title: Summary: Common RNN NLP Architectures, Page: 6018
#     Title: The Encoder-Decoder Model with RNNs, Page: 6051
#       Title: Training the Encoder-Decoder Model, Page: 6192
#     Title: Attention, Page: 6201
#     Title: Summary, Page: 6282
#     Title: Bibliographical and Historical Notes, Page: 6282
#   Title: The Transformer, Page: 6456
#     Title: Attention, Page: 6493
#       Title: Attention more formally, Page: 6537
#     Title: Transformer Blocks, Page: 6634
#     Title: Parallelizing computation using a single matrix X, Page: 6700
#     Title: The input: embeddings for token and position, Page: 6793
#     Title: The Language Modeling Head, Page: 6843
#     Title: Summary, Page: 6931
#     Title: Bibliographical and Historical Notes, Page: 6931
#   Title: Large Language Models, Page: 6946
#     Title: Large Language Models with Transformers, Page: 6953
#     Title: Sampling for LLM Generation, Page: 7002
#       Title: Top-k sampling, Page: 7035
#       Title: Nucleus or top-p sampling, Page: 7047
#       Title: Temperature sampling, Page: 7047
#     Title: Pretraining Large Language Models, Page: 7062
#       Title: Self-supervised training algorithm, Page: 7062
#       Title: Training corpora for large language models, Page: 7079
#       Title: Finetuning, Page: 7195
#     Title: Evaluating Large Language Models, Page: 7253
#     Title: Dealing with Scale, Page: 7287
#       Title: Scaling laws, Page: 7313
#       Title: KV Cache, Page: 7327
#       Title: Parameter Efficient Fine Tuning, Page: 7327
#     Title: Potential Harms from Language Models, Page: 7354
#     Title: Summary, Page: 7418
#     Title: Bibliographical and Historical Notes, Page: 7418
#   Title: Masked Language Models, Page: 7481
#     Title: Bidirectional Transformer Encoders, Page: 7481
#       Title: The architecture for bidirectional masked models, Page: 7492
#     Title: Training Bidirectional Encoders, Page: 7537
#       Title: Masking Words, Page: 7537
#       Title: Next Sentence Prediction, Page: 7588
#       Title: Training Regimes, Page: 7600
#     Title: Contextual Embeddings, Page: 7646
#       Title: Contextual Embeddings and Word Sense, Page: 7663
#       Title: Contextual Embeddings and Word Similarity, Page: 7757
#     Title: Fine-Tuning for Classification, Page: 7805
#       Title: Sequence Classification, Page: 7818
#       Title: Sequence-Pair Classification, Page: 7818
#     Title: Fine-Tuning for Sequence Labelling: Named Entity Recognition, Page: 7858
#       Title: Named Entities, Page: 7858
#       Title: BIO Tagging, Page: 7867
#       Title: Sequence Labeling, Page: 7875
#       Title: Evaluating Named Entity Recognition, Page: 7921
#     Title: Summary, Page: 7921
#     Title: Bibliographical and Historical Notes, Page: 7921
#   Title: Model Alignment, Prompting, and In-Context Learning, Page: 7929
#     Title: Prompting, Page: 7935
#       Title: Learning from Demonstrations: Few-Shot Prompting, Page: 7971
#       Title: In-Context Learning and Induction Heads, Page: 7996
#     Title: Post-training and Model Alignment, Page: 8016
#     Title: Model Alignment: Instruction Tuning, Page: 8056
#       Title: Instructions as Training Data, Page: 8062
#       Title: Evaluation of Instruction-Tuned Models, Page: 8229
#     Title: Chain-of-Thought Prompting, Page: 8252
#     Title: Automatic Prompt Optimization, Page: 8252
#       Title: Candidate Scoring, Page: 8263
#       Title: Prompt Expansion, Page: 8355
#     Title: Evaluating Prompted Language Models, Page: 8369
#     Title: Model Alignment with Human Preferences: RLHF and DPO, Page: 8381
#     Title: Summary, Page: 8387
#     Title: Bibliographical and Historical Notes, Page: 8387
# Title: II NLP Applications, Page: 8395
#   Title: Machine Translation, Page: 8404
#     Title: Language Divergences and Typology, Page: 8430
#       Title: Word Order Typology, Page: 8462
#       Title: Lexical Divergences, Page: 8476
#       Title: Morphological Typology, Page: 8497
#       Title: Referential density, Page: 8535
#     Title: Machine Translation using Encoder-Decoder, Page: 8535
#       Title: Tokenization, Page: 8546
#       Title: Creating the Training data, Page: 8578
#     Title: Details of the Encoder-Decoder Model, Page: 8647
#     Title: Decoding in MT: Beam Search, Page: 8696
#       Title: Minimum Bayes Risk Decoding, Page: 8775
#     Title: Translating in low-resource situations, Page: 8790
#       Title: Data Augmentation, Page: 8790
#       Title: Multilingual models, Page: 8809
#       Title: Sociotechnical issues, Page: 8827
#     Title: MT Evaluation, Page: 8827
#       Title: Using Human Raters to Evaluate MT, Page: 8827
#       Title: Automatic Evaluation, Page: 8844
#       Title: Automatic Evaluation: Embedding-Based Methods, Page: 8870
#     Title: Bias and Ethical Issues, Page: 8897
#     Title: Summary, Page: 9063
#     Title: Bibliographical and Historical Notes, Page: 9063
#     Title: Exercises, Page: 9148
#   Title: Question Answering, Information Retrieval, and RAG, Page: 9242
#     Title: Information Retrieval, Page: 9270
#       Title: Term weighting and document scoring, Page: 9282
#       Title: Document Scoring, Page: 9389
#       Title: Inverted Index, Page: 9436
#       Title: Evaluation of Information-Retrieval Systems, Page: 9436
#     Title: Information Retrieval with Dense Vectors, Page: 9497
#     Title: Answering Questions with RAG, Page: 9605
#       Title: Retrieval-Augmented Generation, Page: 9632
#       Title: Question Answering Datasets, Page: 9682
#     Title: Evaluating Question Answering, Page: 9697
#     Title: Summary, Page: 9717
#     Title: Bibliographical and Historical Notes, Page: 9717
#     Title: Exercises, Page: 9717
#   Title: Chatbots & Dialogue Systems, Page: 9830
#     Title: Properties of Human Conversation, Page: 9861
#     Title: Frame-Based Dialogue Systems, Page: 9924
#       Title: Frames and Slot Filling, Page: 9936
#       Title: Evaluating Task-Based Dialogue, Page: 9951
#     Title: Dialogue Acts and Dialogue State, Page: 9951
#       Title: Dialogue Acts, Page: 9993
#       Title: Dialogue State Tracking, Page: 9993
#       Title: Dialogue Policy: Which act to generate, Page: 10025
#       Title: Natural language generation: Sentence Realization, Page: 10056
#     Title: Chatbots, Page: 10078
#       Title: Training chatbots, Page: 10078
#       Title: Fine Tuning for Quality and Safety, Page: 10162
#       Title: Learning to perform retrieval as part of responding, Page: 10162
#       Title: RLHF, Page: 10176
#       Title: Evaluating Chatbots, Page: 10190
#     Title: Dialogue System Design, Page: 10190
#       Title: Ethical Issues in Dialogue System Design, Page: 10239
#     Title: Summary, Page: 10296
#     Title: Bibliographical and Historical Notes, Page: 10296
#     Title: Exercises, Page: 10296
#   Title: Automatic Speech Recognition and Text-to-Speech, Page: 10469
#     Title: The Automatic Speech Recognition Task, Page: 10479
#     Title: Feature Extraction for ASR: Log Mel Spectrum, Page: 10518
#       Title: Sampling and Quantization, Page: 10518
#       Title: Windowing, Page: 10545
#       Title: Discrete Fourier Transform, Page: 10556
#       Title: Mel Filter Bank and Log, Page: 10636
#     Title: Speech Recognition Architecture, Page: 10672
#       Title: Learning, Page: 10744
#     Title: CTC, Page: 10744
#       Title: CTC Inference, Page: 10807
#       Title: CTC Training, Page: 10855
#       Title: Combining CTC and Encoder-Decoder, Page: 10871
#       Title: Streaming Models: RNN-T for improving CTC, Page: 10871
#     Title: ASR Evaluation: Word Error Rate, Page: 10903
#     Title: TTS, Page: 10945
#       Title: TTS Preprocessing: Text normalization, Page: 10963
#       Title: TTS: Spectrogram prediction, Page: 10993
#       Title: TTS: Vocoding, Page: 11013
#       Title: TTS Evaluation, Page: 11141
#     Title: Other Speech Tasks, Page: 11141
#     Title: Summary, Page: 11167
#     Title: Bibliographical and Historical Notes, Page: 11167
#     Title: Exercises, Page: 11167
# Title: III Annotating Linguistic Structure, Page: 11385
#   Title: Sequence Labeling for Parts of Speech and Named Entities, Page: 11400
#     Title: (Mostly) English Word Classes, Page: 11400
#     Title: Part-of-Speech Tagging, Page: 11428
#     Title: Named Entities and Named Entity Tagging, Page: 11474
#     Title: HMM Part-of-Speech Tagging, Page: 11494
#       Title: Markov Chains, Page: 11494
#       Title: The Hidden Markov Model, Page: 11564
#       Title: The components of an HMM tagger, Page: 11575
#       Title: HMM tagging as decoding, Page: 11645
#       Title: The Viterbi Algorithm, Page: 11657
#       Title: Working through an example, Page: 11670
#     Title: Conditional Random Fields (CRFs), Page: 12058
#       Title: Features in a CRF POS Tagger, Page: 12075
#       Title: Features for CRF Named Entity Recognizers, Page: 12086
#       Title: Inference and Training for CRFs, Page: 12097
#     Title: Evaluation of Named Entity Recognition, Page: 12113
#     Title: Further Details , Page: 12113
#       Title: Rule-based Methods, Page: 12138
#       Title: POS Tagging for Morphologically Rich Languages, Page: 12138
#     Title: Summary, Page: 12163
#     Title: Bibliographical and Historical Notes, Page: 12163
#     Title: Exercises, Page: 12163
#   Title: Context-Free Grammars and Constituency Parsing, Page: 12341
#     Title: Constituency, Page: 12353
#     Title: Context-Free Grammars, Page: 12353
#       Title: Formal Definition of Context-Free Grammar, Page: 12390
#     Title: Treebanks, Page: 12390
#     Title: Grammar Equivalence and Normal Form, Page: 12409
#     Title: Ambiguity, Page: 12417
#     Title: CKY Parsing: A Dynamic Programming Approach, Page: 12435
#       Title: Conversion to Chomsky Normal Form, Page: 12435
#       Title: CKY Recognition, Page: 12446
#       Title: CKY Parsing, Page: 12474
#       Title: CKY in Practice, Page: 12711
#     Title: Span-Based Neural Constituency Parsing, Page: 13152
#       Title: Computing Scores for a Span, Page: 13152
#       Title: Integrating Span Scores into a Parse, Page: 13240
#     Title: Evaluating Parsers, Page: 13261
#     Title: Heads and Head-Finding, Page: 13290
#     Title: Summary, Page: 13313
#     Title: Bibliographical and Historical Notes, Page: 13313
#     Title: Exercises, Page: 13313
#   Title: Dependency Parsing, Page: 13438
#     Title: Dependency Relations, Page: 13450
#       Title: Dependency Formalisms, Page: 13454
#       Title: Projectivity, Page: 13462
#       Title: Dependency Treebanks, Page: 13475
#     Title: Transition-Based Dependency Parsing, Page: 13487
#       Title: Creating an Oracle, Page: 13589
#       Title: A feature-based classifier, Page: 13602
#       Title: A neural classifier, Page: 13613
#       Title: Advanced Methods in Transition-Based Parsing, Page: 13689
#     Title: Graph-Based Dependency Parsing, Page: 13707
#       Title: Parsing via finding the maximum spanning tree, Page: 13716
#       Title: A feature-based algorithm for assigning scores, Page: 13753
#       Title: A neural algorithm for assigning scores, Page: 13758
#     Title: Evaluation, Page: 13832
#     Title: Summary, Page: 13842
#     Title: Bibliographical and Historical Notes, Page: 13842
#     Title: Exercises, Page: 13842
#   Title: Information Extraction: Relations, Events, and Time, Page: 13958
#     Title: Relation Extraction, Page: 13965
#     Title: Relation Extraction Algorithms, Page: 14023
#       Title: Using Patterns to Extract Relations, Page: 14023
#       Title: Relation Extraction via Supervised Learning, Page: 14034
#       Title: Semisupervised Relation Extraction via Bootstrapping, Page: 14064
#       Title: Distant Supervision for Relation Extraction, Page: 14097
#       Title: Unsupervised Relation Extraction, Page: 14123
#       Title: Evaluation of Relation Extraction, Page: 14146
#     Title: Extracting Events, Page: 14146
#     Title: Representing Time, Page: 14154
#       Title: Reichenbach's reference point, Page: 14168
#     Title: Representing Aspect, Page: 14237
#     Title: Temporally Annotated Datasets: TimeBank, Page: 14258
#     Title: Automatic Temporal Analysis, Page: 14276
#       Title: Extracting Temporal Expressions, Page: 14276
#       Title: Temporal Normalization, Page: 14312
#       Title: Temporal Ordering of Events, Page: 14348
#     Title: Template Filling, Page: 14366
#       Title: Machine Learning Approaches to Template Filling, Page: 14366
#       Title: Earlier Finite-State Template-Filling Systems, Page: 14390
#     Title: Summary, Page: 14404
#     Title: Bibliographical and Historical Notes, Page: 14404
#     Title: Exercises, Page: 14404
#   Title: Semantic Role Labeling, Page: 14546
#     Title: Semantic Roles, Page: 14571
#     Title: Diathesis Alternations, Page: 14571
#     Title: Semantic Roles: Problems with Thematic Roles, Page: 14597
#     Title: The Proposition Bank, Page: 14607
#     Title: FrameNet, Page: 14624
#     Title: Semantic Role Labeling, Page: 14670
#       Title: A Feature-based Algorithm for Semantic Role Labeling, Page: 14670
#       Title: A Neural Algorithm for Semantic Role Labeling, Page: 14732
#       Title: Evaluation of Semantic Role Labeling, Page: 14760
#     Title: Selectional Restrictions, Page: 14760
#       Title: Representing Selectional Restrictions, Page: 14778
#       Title: Selectional Preferences, Page: 14795
#     Title: Primitive Decomposition of Predicates, Page: 14843
#     Title: Summary, Page: 14861
#     Title: Bibliographical and Historical Notes, Page: 14861
#     Title: Exercises, Page: 14861
#   Title: Lexicons for Sentiment, Affect, and Connotation, Page: 15067
#     Title: Defining Emotion, Page: 15086
#     Title: Available Sentiment and Affect Lexicons, Page: 15178
#     Title: Creating Affect Lexicons by Human Labeling, Page: 15205
#     Title: Semi-supervised Induction of Affect Lexicons, Page: 15236
#       Title: Semantic Axis Methods, Page: 15236
#       Title: Label Propagation, Page: 15250
#       Title: Other Methods, Page: 15270
#     Title: Supervised Learning of Word Sentiment, Page: 15580
#       Title: Log Odds Ratio Informative Dirichlet Prior, Page: 15614
#     Title: Using Lexicons for Sentiment Recognition, Page: 17112
#     Title: Using Lexicons for Affect Recognition, Page: 17125
#     Title: Lexicon-based methods for Entity-Centric Affect, Page: 17143
#     Title: Connotation Frames, Page: 17143
#     Title: Summary, Page: 17363
#     Title: Bibliographical and Historical Notes, Page: 17363
#     Title: Exercises, Page: 17363
#   Title: Coreference Resolution and Entity Linking, Page: 17543
#     Title: Coreference Phenomena: Linguistic Background, Page: 17642
#       Title: Types of Referring Expressions, Page: 17642
#       Title: Information Status, Page: 17665
#       Title: Complications: Non-Referring Expressions, Page: 17710
#       Title: Linguistic Properties of the Coreference Relation, Page: 17738
#     Title: Coreference Tasks and Datasets, Page: 17784
#     Title: Mention Detection, Page: 17814
#     Title: Architectures for Coreference Algorithms, Page: 17901
#       Title: The Mention-Pair Architecture, Page: 17901
#       Title: The Mention-Rank Architecture, Page: 17941
#       Title: Entity-based Models, Page: 18011
#     Title: Classifiers using hand-built features, Page: 18011
#     Title: A neural mention-ranking algorithm, Page: 18044
#       Title: Computing span representations, Page: 18044
#       Title: Computing the mention and antecedent scores m and c , Page: 18065
#       Title: Learning, Page: 18106
#     Title: Entity Linking, Page: 18138
#       Title: Linking based on Anchor Dictionaries and Web Graph, Page: 18138
#       Title: Neural Graph-based linking, Page: 18165
#     Title: Evaluation of Coreference Resolution, Page: 18213
#     Title: Winograd Schema problems, Page: 18258
#     Title: Gender Bias in Coreference, Page: 18297
#     Title: Summary, Page: 18332
#     Title: Bibliographical and Historical Notes, Page: 18332
#     Title: Exercises, Page: 18554
#   Title: Discourse Coherence, Page: 18586
#     Title: Coherence Relations, Page: 18631
#       Title: Rhetorical Structure Theory, Page: 18631
#       Title: Penn Discourse TreeBank (PDTB), Page: 18714
#     Title: Discourse Structure Parsing, Page: 18734
#       Title: EDU segmentation for RST parsing, Page: 18763
#       Title: RST parsing, Page: 18763
#       Title: PDTB discourse parsing, Page: 18888
#     Title: Centering and Entity-Based Coherence, Page: 18928
#       Title: Centering, Page: 18928
#       Title: Entity Grid model, Page: 18976
#       Title: Evaluating Neural and Entity-based coherence, Page: 19062
#     Title: Representation learning models for local coherence, Page: 19062
#     Title: Global Coherence, Page: 19113
#       Title: Argumentation Structure, Page: 19193
#       Title: The structure of scientific discourse, Page: 19231
#     Title: Summary, Page: 19290
#     Title: Bibliographical and Historical Notes, Page: 19290
#     Title: Exercises, Page: 19290
#   Title: Bibliography, Page: 19528
#   Title: Subject Index, Page: 19528

# %%
from PyPDF2 import PdfReader
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS

def extract_toc_and_text(pdf_path):
    """
    Trích xuất mục lục và nội dung từ file PDF.

    Args:
        pdf_path: Đường dẫn tới file PDF.

    Returns:
        List: Danh sách các mục lục với tiêu đề, số trang bắt đầu và nội dung.
    """
    reader = PdfReader(pdf_path)
    toc_data = []

    # Trích xuất mục lục
    if hasattr(reader, "outline"):
        outline = reader.outline

        for item in outline:
            if isinstance(item, dict):
                title = item.get('/Title', 'Unknown Title')
                page_ref = item.get('/Page')
                if page_ref:
                    # Lấy số trang thực tế từ đối tượng IndirectObject
                    start_page = reader.get_page_number(page_ref) + 1  # Số trang bắt đầu từ 1
                    toc_data.append({"title": title, "start_page": start_page})
    else:
        print("Không tìm thấy mục lục trong file PDF.")
        return None

    # Trích xuất nội dung cho từng mục lục
    for i, toc_item in enumerate(toc_data):
        start_page = toc_item["start_page"] - 1  # Chuyển về chỉ số bắt đầu từ 0
        end_page = toc_data[i + 1]["start_page"] - 1 if i + 1 < len(toc_data) else len(reader.pages)

        # Ghép nội dung từ các trang thuộc mục lục này
        text = ""
        for page_num in range(start_page, end_page):
            text += reader.pages[page_num].extract_text()
        toc_item["text"] = text

    return toc_data

def build_combined_index(pdf_path: str, index_path: str):
    """
    Xây dựng một vector store duy nhất cho toàn bộ nội dung PDF, được chia nhỏ theo mục lục lớn và nhỏ.

    Args:
        pdf_path: Đường dẫn tới file PDF.
        index_path: Đường dẫn lưu chỉ mục.
    """
    # Initialize embeddings
    embeddings = HuggingFaceEmbeddings(
        model_name="sentence-transformers/all-MiniLM-L6-v2"
    )

    # Extract TOC and associated text
    toc_data = extract_toc_and_text(pdf_path)
    if not toc_data:
        print("Không có mục lục để xử lý.")
        return

    # Initialize vector store
    combined_texts = []

    for toc_item in toc_data:
        title = toc_item["title"]
        text = toc_item["text"]

        # Split text into chunks
        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=500,
            chunk_overlap=50
        )
        chunks = text_splitter.split_text(text)

        # Append title to each chunk for context
        titled_chunks = [f"{title}: {chunk}" for chunk in chunks]
        combined_texts.extend(titled_chunks)

    # Create and save vector store
    vector_store = FAISS.from_texts(combined_texts, embeddings)
    vector_store.save_local(index_path)
    print(f"Combined index saved to {index_path}")

# Example usage
pdf_path = "nlp_book.pdf"
index_path = "faiss_combined_index"
build_combined_index(pdf_path, index_path)
# Out:
# Combined index saved to faiss_combined_index
